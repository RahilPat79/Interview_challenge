# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv(r'C:\Users\rahil\Desktop\Nexus-Edge\data.csv')
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# ...

# %%
y=df['state']
print(y.unique())
# Out:
# ['failed' 'canceled' 'successful' 'live' 'undefined' 'suspended']

# %%
y.value_counts()
# Out:
# failed        197719
# successful    133956
# canceled       38779
# undefined       3562
# live            2799
# suspended       1846
# Name: state, dtype: int64

# %%
df=pd.DataFrame(df)
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# ...

# %%
df.sort_values(by=['state'],ascending=True,inplace=True)
df.head()
# Out:
#                 ID                                               name  \
# 203282  2035319645                    Criminals: The Heist (Canceled)
# 206625  2052723338                             Edible Kale (Canceled)
# 310606   652188085                                   Magical Babe Box
# 206630  2052735655  'CAMELOT FOREVER: PENDRAGON'S RETURN' - a fant...
# 206634  2052747308  A Debut EP...Welcome To My Rebel Side! (Canceled)
#
#               category main_category currency    deadline     goal  \
# 203282     Video Games         Games      GBP  2013-08-25  75000.0
# 206625            Food          Food      USD  2014-08-03     12.0
# 310606  Product Design        Design      USD  2016-08-02   1100.0
# 206630         Fiction    Publishing      USD  2017-12-14   7900.0
# 206634           Music         Music      USD  2011-08-07  11500.0
#
#                    launched  pledged     state  backers country  usd pledged  \
# ...

# %%
num_category=y.factorize()

# %%
num_category
# Out:
# (array([0, 0, 0, ..., 0, 0, 0], dtype=int64),
#  Index(['failed', 'canceled', 'successful', 'live', 'undefined', 'suspended'], dtype='object'))

# %%
df['state'].factorize()
df['state'].head()
# Out:
# 203282    canceled
# 206625    canceled
# 310606    canceled
# 206630    canceled
# 206634    canceled
# Name: state, dtype: object

# %%
df['state'].value_counts()
# Out:
# failed        197719
# successful    133956
# canceled       38779
# undefined       3562
# live            2799
# suspended       1846
# Name: state, dtype: int64

# %%
df.head()
# Out:
#                 ID                                               name  \
# 203282  2035319645                    Criminals: The Heist (Canceled)
# 206625  2052723338                             Edible Kale (Canceled)
# 310606   652188085                                   Magical Babe Box
# 206630  2052735655  'CAMELOT FOREVER: PENDRAGON'S RETURN' - a fant...
# 206634  2052747308  A Debut EP...Welcome To My Rebel Side! (Canceled)
#
#               category main_category currency    deadline     goal  \
# 203282     Video Games         Games      GBP  2013-08-25  75000.0
# 206625            Food          Food      USD  2014-08-03     12.0
# 310606  Product Design        Design      USD  2016-08-02   1100.0
# 206630         Fiction    Publishing      USD  2017-12-14   7900.0
# 206634           Music         Music      USD  2011-08-07  11500.0
#
#                    launched  pledged     state  backers country  usd pledged  \
# ...

# %%
df.drop('ID',axis=1)
# Out:
#                                                      name          category  \
# 203282                    Criminals: The Heist (Canceled)       Video Games
# 206625                             Edible Kale (Canceled)              Food
# 310606                                   Magical Babe Box    Product Design
# 206630  'CAMELOT FOREVER: PENDRAGON'S RETURN' - a fant...           Fiction
# 206634  A Debut EP...Welcome To My Rebel Side! (Canceled)             Music
# 206637            Help Me Fund My Second Album (Canceled)  Electronic Music
# 47514       Silver reflective URBN CITY poster (Canceled)    Graphic Design
# 47515   Lignum by Remoria VR: The VR controller that w...           Gadgets
# 119850                      Primoris: Core Set (Canceled)    Tabletop Games
# 310590  Birds. Guns. Kids. "The Hunting Trip" a film (...    Narrative Film
# 310588                             SterriaLand (Canceled)       Video Games
# ...

# %%
np.random.seed(45)
df=df.drop('ID',axis=1)
df=df.reindex(np.random.permutation(df.index))
df.reset_index(inplace=True, drop=True)
df.head()
# Out:
#                                                 name     category  \
# 0                            RPG CT: Demon's Revenge  Video Games
# 1                                 Blackwake [Reboot]  Video Games
# 2                                        Tempus-Cieo        Games
# 3  NINJA SPHERE: Next Generation Control of Your ...     Hardware
# 4  The Most Realistic Pokeball and Super Mario In...      Candles
#
#   main_category currency    deadline      goal             launched   pledged  \
# 0         Games      USD  2014-10-03   12000.0  2014-09-03 00:03:22    2487.0
# 1         Games      AUD  2015-09-03   10000.0  2015-08-04 00:04:12  171422.6
# 2         Games      GBP  2015-08-07    1000.0  2015-07-08 20:02:27      82.0
# 3    Technology      AUD  2014-01-12  115000.0  2013-11-13 03:33:33  702937.5
# 4        Crafts      CAD  2016-12-22     600.0  2016-11-22 20:05:16     265.0
#
#         state  backers country  usd pledged  usd_pledged_real  usd_goal_real
# ...

# %%
df.head()
df=df.drop('pledged',axis=1)

# %%
df=df.drop('currency',axis=1)
df=df.drop('usd pledged',axis=1)
df=df.drop('goal',axis=1)
df.head()
# Out:
#                                                 name     category  \
# 0                            RPG CT: Demon's Revenge  Video Games
# 1                                 Blackwake [Reboot]  Video Games
# 2                                        Tempus-Cieo        Games
# 3  NINJA SPHERE: Next Generation Control of Your ...     Hardware
# 4  The Most Realistic Pokeball and Super Mario In...      Candles
#
#   main_category    deadline             launched  backers country  \
# 0         Games  2014-10-03  2014-09-03 00:03:22      149      US
# 1         Games  2015-09-03  2015-08-04 00:04:12     4080      AU
# 2         Games  2015-08-07  2015-07-08 20:02:27        5      GB
# 3    Technology  2014-01-12  2013-11-13 03:33:33     1772      AU
# 4        Crafts  2016-12-22  2016-11-22 20:05:16        7      CA
#
#    usd_pledged_real  usd_goal_real
# 0           2487.00       12000.00
# 1         119716.88        6983.73
# 2            127.24        1551.69
# ...

# %%
X=df

# %%
X
# Out:
#                                                      name        category  \
# 0                                 RPG CT: Demon's Revenge     Video Games
# 1                                      Blackwake [Reboot]     Video Games
# 2                                             Tempus-Cieo           Games
# 3       NINJA SPHERE: Next Generation Control of Your ...        Hardware
# 4       The Most Realistic Pokeball and Super Mario In...         Candles
# 5       A project for the fabrication of prototypes fo...       Wearables
# 6                                       HÖG TID ATT ÄLSKA         Musical
# 7       Dithyrambalina-Musical Architecture for New Or...             Art
# 8                                    Smart Card Solutions        Software
# 9                                         Help My Wedding            Apps
# 10                                              Urban Con          Crafts
# 11        Building of Song Festival - Pay the Performers!             Pop
# ...

# %%
import math
#math.ceil((X['usd_goal_real']*100)/100)
usd_goal_real=X['usd_goal_real'].astype(float)
usd_goal_real
# Out:
# 0         1.200000e+04
# 1         6.983730e+03
# 2         1.551690e+03
# 3         1.010811e+05
# 4         4.439800e+02
# 5         1.250000e+05
# 6         1.146870e+03
# 7         5.000000e+04
# 8         1.544306e+04
# 9         2.000000e+04
# 10        8.000000e+03
# 11        7.000000e+02
# 12        1.500000e+03
# 13        8.000000e+02
# 14        1.500000e+04
# 15        2.500000e+03
# 16        1.873010e+04
# 17        2.000000e+02
# 18        8.000000e+02
# 19        1.000000e+03
# 20        5.000000e+02
# 21        8.500000e+03
# 22        1.000000e+08
# 23        4.000000e+04
# 24        2.500000e+03
# 25        6.500000e+04
# 26        7.791000e+01
# 27        1.111296e+04
# 28        7.500000e+04
# 29        2.230152e+04
#               ...
# 378631    3.196200e+03
# 378632    3.911996e+04
# 378633    1.000000e+05
# 378634    2.100000e+04
# 378635    3.069980e+04
# 378636    4.000000e+03
# 378637    2.000000e+04
# 378638    4.000000e+03
# 378639    5.000000e+03
# ...

# %%
X.shape
# Out:
# (378661, 9)

# %%
X.insert(9,'goal',(X['usd_goal_real']).astype(int))
X
# Out:
#                                                      name        category  \
# 0                                 RPG CT: Demon's Revenge     Video Games
# 1                                      Blackwake [Reboot]     Video Games
# 2                                             Tempus-Cieo           Games
# 3       NINJA SPHERE: Next Generation Control of Your ...        Hardware
# 4       The Most Realistic Pokeball and Super Mario In...         Candles
# 5       A project for the fabrication of prototypes fo...       Wearables
# 6                                       HÖG TID ATT ÄLSKA         Musical
# 7       Dithyrambalina-Musical Architecture for New Or...             Art
# 8                                    Smart Card Solutions        Software
# 9                                         Help My Wedding            Apps
# 10                                              Urban Con          Crafts
# 11        Building of Song Festival - Pay the Performers!             Pop
# ...

# %%
X=X.drop('usd_goal_real',axis=1)

# %%
X
# Out:
#                                                      name        category  \
# 0                                 RPG CT: Demon's Revenge     Video Games
# 1                                      Blackwake [Reboot]     Video Games
# 2                                             Tempus-Cieo           Games
# 3       NINJA SPHERE: Next Generation Control of Your ...        Hardware
# 4       The Most Realistic Pokeball and Super Mario In...         Candles
# 5       A project for the fabrication of prototypes fo...       Wearables
# 6                                       HÖG TID ATT ÄLSKA         Musical
# 7       Dithyrambalina-Musical Architecture for New Or...             Art
# 8                                    Smart Card Solutions        Software
# 9                                         Help My Wedding            Apps
# 10                                              Urban Con          Crafts
# 11        Building of Song Festival - Pay the Performers!             Pop
# ...

# %%
X['main_category'].value_counts()
# Out:
# Film & Video    63585
# Music           51918
# Publishing      39874
# Games           35231
# Technology      32569
# Design          30070
# Art             28153
# Food            24602
# Fashion         22816
# Theater         10913
# Comics          10819
# Photography     10779
# Crafts           8809
# Journalism       4755
# Dance            3768
# Name: main_category, dtype: int64
